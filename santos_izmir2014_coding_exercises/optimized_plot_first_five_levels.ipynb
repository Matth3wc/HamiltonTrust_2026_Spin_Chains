# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb
from itertools import combinations
from scipy.sparse import coo_matrix
from scipy.sparse.linalg import eigsh
from scipy.linalg import svdvals

try:
    from numba import njit
except Exception:
    def njit(*args, **kwargs):
        if args and len(args) == 1 and callable(args[0]) and not kwargs:
            return args[0]

        def decorator(func):
            return func

        return decorator


@njit(cache=True)
def _build_cut_map_numba(states, L, ell):
    dim = states.shape[0]
    row_a = np.empty(dim, dtype=np.int32)
    row_b = np.empty(dim, dtype=np.int32)
    left_shift = L - ell
    left_mask = (np.uint64(1) << np.uint64(left_shift)) - np.uint64(1)
    right_mask = (np.uint64(1) << np.uint64(ell)) - np.uint64(1)

    for i in range(dim):
        state = states[i]
        row_a[i] = int((state >> np.uint64(left_shift)) & left_mask)
        row_b[i] = int(state & right_mask)

    return row_a, row_b


@njit(cache=True)
def _build_hamiltonian_triplets(states, index_map, L, pairs1, pairs2, J1xy, J1z, J2xy, J2z, kind_flag):
    dim = states.shape[0]
    n1 = pairs1.shape[0]
    n2 = pairs2.shape[0]
    if kind_flag == 0:
        max_nnz = dim + dim * n1
    else:
        max_nnz = dim + dim * (n1 + n2)

    rows = np.empty(max_nnz, dtype=np.int32)
    cols = np.empty(max_nnz, dtype=np.int32)
    vals = np.empty(max_nnz, dtype=np.float64)
    diag = np.zeros(dim, dtype=np.float64)
    one = np.uint64(1)
    cursor = 0

    for i in range(dim):
        state = states[i]

        for p in range(n1):
            a = pairs1[p, 0]
            b = pairs1[p, 1]
            pa = np.uint64(L - 1 - a)
            pb = np.uint64(L - 1 - b)
            bit_a = (state >> pa) & one
            bit_b = (state >> pb) & one
            if bit_a == bit_b:
                diag[i] += J1z / 4.0
            else:
                diag[i] -= J1z / 4.0
                if J1xy != 0.0:
                    flipped = state ^ ((one << pa) | (one << pb))
                    j = index_map[np.int64(flipped)]
                    rows[cursor] = i
                    cols[cursor] = j
                    vals[cursor] = J1xy / 2.0
                    cursor += 1

        if kind_flag == 1:
            for p in range(n2):
                a = pairs2[p, 0]
                b = pairs2[p, 1]
                pa = np.uint64(L - 1 - a)
                pb = np.uint64(L - 1 - b)
                bit_a = (state >> pa) & one
                bit_b = (state >> pb) & one
                if bit_a == bit_b:
                    diag[i] += J2z / 4.0
                else:
                    diag[i] -= J2z / 4.0
                    if J2xy != 0.0:
                        flipped = state ^ ((one << pa) | (one << pb))
                        j = index_map[np.int64(flipped)]
                        rows[cursor] = i
                        cols[cursor] = j
                        vals[cursor] = J2xy / 2.0
                        cursor += 1

    for i in range(dim):
        rows[cursor] = i
        cols[cursor] = i
        vals[cursor] = diag[i]
        cursor += 1

    return rows[:cursor], cols[:cursor], vals[:cursor]


class FastXXZChain:
    """Optimized fixed-Nup XXZ chain with cached basis, Hamiltonian, and entropy maps."""

    def __init__(self, L, Nup, periodic=True, J1xy=1.0, J1z=0.5, J2xy=0.0, J2z=0.0):
        self.L = int(L)
        self.Nup = int(Nup)
        self.periodic = bool(periodic)
        self.J1xy = float(J1xy)
        self.J1z = float(J1z)
        self.J2xy = float(J2xy)
        self.J2z = float(J2z)

        self.states = self._build_basis_states()
        self.index_map = self._build_index_map()
        self.pairs1 = np.asarray(self._pairs(1), dtype=np.int32)
        self.pairs2 = np.asarray(self._pairs(2), dtype=np.int32)
        self._entropy_cache = {}

    def _build_basis_states(self):
        states = []
        for positions in combinations(range(self.L), self.Nup):
            value = 0
            for site in positions:
                value |= 1 << (self.L - 1 - site)
            states.append(value)
        return np.asarray(states, dtype=np.uint64)

    def _build_index_map(self):
        size = 1 << self.L
        index_map = -np.ones(size, dtype=np.int32)
        for i, state in enumerate(self.states):
            index_map[int(state)] = i
        return index_map

    def _pairs(self, order):
        if order == 1:
            if self.periodic:
                return [(i, (i + 1) % self.L) for i in range(self.L)]
            return [(i, i + 1) for i in range(self.L - 1)]
        if order == 2:
            if self.periodic:
                return [(i, (i + 2) % self.L) for i in range(self.L)]
            return [(i, i + 2) for i in range(self.L - 2)]
        raise ValueError('order must be 1 or 2')

    def hilbert_dimension(self):
        return int(self.states.size)

    def build_hamiltonian(self, kind='nnn'):
        if kind not in {'nn', 'nnn'}:
            raise ValueError("kind must be 'nn' or 'nnn'.")

        kind_flag = 0 if kind == 'nn' else 1
        rows, cols, vals = _build_hamiltonian_triplets(
            self.states,
            self.index_map,
            self.L,
            self.pairs1,
            self.pairs2,
            self.J1xy,
            self.J1z,
            self.J2xy,
            self.J2z,
            kind_flag,
        )
        dim = self.hilbert_dimension()
        return coo_matrix((vals, (rows, cols)), shape=(dim, dim)).tocsr()

    def ground_state(self, kind='nnn'):
        H = self.build_hamiltonian(kind=kind)
        if H.shape[0] == 1:
            return float(H[0, 0]), np.array([1.0], dtype=float)
        eigvals, eigvecs = eigsh(H, k=1, which='SA', tol=1e-12, maxiter=100000)
        return float(eigvals[0]), eigvecs[:, 0]

    def _cut_map(self, ell):
        if ell in self._entropy_cache:
            return self._entropy_cache[ell]

        row_a, row_b = _build_cut_map_numba(self.states, self.L, ell)
        mapping = {
            'rowA': row_a,
            'rowB': row_b,
            'dimA': 1 << ell,
            'dimB': 1 << (self.L - ell),
        }
        self._entropy_cache[ell] = mapping
        return mapping

    def entropy_curve(self, kind='nnn', blocks=None):
        ground_energy, sector_state = self.ground_state(kind=kind)
        if blocks is None:
            blocks = range(1, self.L)
        block_list = sorted({int(block) for block in blocks if 0 < block < self.L})

        entropies = np.zeros(len(block_list), dtype=float)
        for i, ell in enumerate(block_list):
            data = self._cut_map(ell)
            psi_matrix = np.zeros((data['dimA'], data['dimB']), dtype=complex)
            psi_matrix[data['rowA'], data['rowB']] = sector_state
            svals = svdvals(psi_matrix)
            probs = svals**2
            probs = probs[probs > 1e-14]
            entropies[i] = float(-np.sum(probs * np.log(probs)))

        block_sizes = np.asarray(block_list, dtype=int)
        upper_bound = np.log(2.0) * np.minimum(block_sizes, self.L - block_sizes)
        return block_sizes, entropies, upper_bound, ground_energy

    def plot_entropy(self, kind='nnn', blocks=None, title=None):
        block_sizes, entropies, upper_bound, ground_energy = self.entropy_curve(kind=kind, blocks=blocks)
        fig, ax = plt.subplots(figsize=(8, 5))
        ax.plot(block_sizes, entropies, marker='o', linewidth=2, label='Entropy')
        ax.plot(block_sizes, upper_bound, '--', linewidth=2, label='Upper Bound')
        ax.set_xlabel('Block size l')
        ax.set_ylabel('S(l)')
        ax.set_title(title or f'Entanglement Entropy (E0 = {ground_energy:.6f})')
        ax.grid(True, alpha=0.3)
        ax.legend()
        plt.tight_layout()
        plt.show()


def half_filling_dimension(L):
    return comb(L, L // 2)


def recommended_max_L(limit_dim=200000):
    best = 0
    for L in range(2, 40, 2):
        if half_filling_dimension(L) <= limit_dim:
            best = L
    return best

# %%
# Interactive 3D surfaces for the first five energy levels over (J1xy, J1z) with J2 fixed to zero.
from IPython.display import HTML, display
import plotly.graph_objects as go
from scipy.sparse.linalg import eigsh
from pathlib import Path
import re

L = 6
chain = FastXXZChain(
    L=L,
    Nup=L // 2,
    periodic=True,
    J1xy=0.0,
    J1z=0.0,
    J2xy=0.0,
    J2z=0.0,
)

plots_dir = Path.cwd() / "plots"
plots_dir.mkdir(parents=True, exist_ok=True)

J1xy_values = np.round(np.linspace(-4.0, 4.0, 250), 3)
J1z_values = np.round(np.linspace(-4.0, 4.0, 250), 3)
block = L // 2

entropy_surfaces = [np.full((len(J1z_values), len(J1xy_values)), np.nan, dtype=float) for _ in range(5)]

for i, J1z in enumerate(J1z_values):
    for j, J1xy in enumerate(J1xy_values):
        if abs(J1xy) < 1e-12 and abs(J1z) < 1e-12:
            continue

        chain.J1xy = float(J1xy)
        chain.J1z = float(J1z)
        chain.J2xy = 0.0
        chain.J2z = 0.0

        H = chain.build_hamiltonian(kind="nn")
        k = min(5, H.shape[0] - 1)
        if k < 1:
            continue

        evals, evecs = eigsh(H, k=k, which="SA", tol=1e-10, maxiter=50000)
        order = np.argsort(evals)
        evecs = evecs[:, order]

        cut_map = chain._cut_map(block)
        psi_shape = (cut_map['dimA'], cut_map['dimB'])

        for level in range(min(5, evecs.shape[1])):
            psi_matrix = np.zeros(psi_shape, dtype=complex)
            psi_matrix[cut_map['rowA'], cut_map['rowB']] = evecs[:, level]
            svals = np.linalg.svd(psi_matrix, compute_uv=False)
            probs = svals**2
            probs = probs[probs > 1e-14]
            entropy_surfaces[level][i, j] = float(-np.sum(probs * np.log(probs)))

level_titles = [
    'Ground state entropy',
    '1st excited state entropy',
    '2nd excited state entropy',
    '3rd excited state entropy',
    '4th excited state entropy',
]

def _slugify(text):
    slug = re.sub(r'[^a-z0-9]+', '_', text.lower()).strip('_')
    return slug or 'plot'

for level, surface in enumerate(entropy_surfaces):
    title = f'{level_titles[level]} at L={L} with J2 = 0'
    fig = go.Figure(
        data=[
            go.Surface(
                x=J1xy_values,
                y=J1z_values,
                z=surface,
                colorscale='Viridis',
                colorbar=dict(title='Entropy'),
            )
        ]
    )
    fig.update_layout(
        title=title,
        scene=dict(
            xaxis_title='J1xy',
            yaxis_title='J1z',
            zaxis_title='Half-chain entropy',
            camera=dict(eye=dict(x=1.6, y=1.6, z=1.0)),
        ),
        margin=dict(l=0, r=0, b=0, t=40),
    )

    plot_path = plots_dir / f"{_slugify(title)}.html"
    fig.write_html(str(plot_path), include_plotlyjs='cdn', full_html=True)
    print(f"Saved {plot_path}")
    display(HTML(fig.to_html(include_plotlyjs='cdn', full_html=False)))
# Out:
# Saved /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/santos_izmir2014_coding_exercises/plots/ground_state_entropy_at_l_6_with_j2_0.html
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8acb0df0-cb6d-4de9-886a-1d4896c3017f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8acb0df0-cb6d-4de9-886a-1d4896c3017f")) {                    Plotly.newPlot(                        "8acb0df0-cb6d-4de9-886a-1d4896c3017f",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMBYObTIdr4PwLByaJHtfA\u002fACKwcWmQ7D8ArhxbZzvcOwIPAyqFFtg7A2\u002fl+arx0DsAzMzMzMzMOwIts5\u002fup8Q3A46WbxCCwDcA730+Nl24NwJMYBFYOLQ3AtvP91HjpDMAOLbKd76cMwGZmZmZmZgzAvp8aL90kDMAX2c73U+MLwG8Sg8DKoQvAx0s3iUFgC8AfhetRuB4LwEJg5dAi2wrAmpmZmZmZCsDy0k1iEFgKwEoMAiuHFgrAokW28\\u002fupA8CcxCCwcmgDwPT91HjpJgPAF9nO91PjAsBvEoPAyqECwMdLN4lBYALAH4XrUbgeAsB3vp8aL90BwM\u002f3U+OlmwHAJzEIrBxaAcB\u002farx0kxgBwKJFtvP91ADA+n5qvHSTAMBSuB6F61EAwKrx0k1iEADABFYOLbKd\u002f7+0yHa+nxr\u002fv2Q730+Nl\u002f6\u002fFK5H4XoU\u002fr9aZDvfT439vwrXo3A9Cv2\u002fukkMAiuH\u002fL9qvHSTGAT8vxsv3SQGgfu\u002fy6FFtvP9+r97FK5H4Xr6v8HKoUW28\u002fm\u002fcT0K16Nw+b8hsHJoke34v9Ei2\u002fl+avi\u002fgZVDi2zn978xCKwcWmT3v+F6FK5H4fa\u002fke18PzVe9r\u002fXo3A9Ctf1v4cW2c73U\u002fW\u002fN4lBYOXQ9L\u002fn+6nx0k30v5huEoPAyvO\u002fSOF6FK5H87\u002f4U+Olm8Tyv6jGSzeJQfK\u002f7nw\u002fNV668b+e76fGSzfxv05iEFg5tPC\u002f\u002ftR46SYx8L9cj8L1KFzvv7x0kxgEVu6\u002fHVpkO99P7b99PzVeuknsvwisHFpkO+u\u002faJHtfD816r\u002fJdr6fGi\u002fpvylcj8L1KOi\u002fiUFg5dAi57\u002fpJjEIrBzmv0oMAiuHFuW\u002fqvHSTWIQ5L81XrpJDALjv5ZDi2zn++G\u002f9ihcj8L14L+sHFpkO9\u002ffv23n+6nx0t2\u002fLbKd76fG27\u002fufD81XrrZvwRWDi2ynde\u002fxSCwcmiR1b+F61G4HoXTv0a28\u002f3UeNG\u002fDAIrhxbZzr+Nl24Sg8DKvw4tsp3vp8a\u002fj8L1KFyPwr956SYxCKy8v3sUrkfherS\u002f+n5qvHSTqL\u002f8qfHSTWKQv\u002fyp8dJNYpA\u002f+n5qvHSTqD97FK5H4Xq0P3npJjEIrLw\u002fj8L1KFyPwj8OLbKd76fGP42XbhKDwMo\u002fDAIrhxbZzj9GtvP91HjRP4XrUbgehdM\u002fxSCwcmiR1T8EVg4tsp3XP+58PzVeutk\u002fLbKd76fG2z9t5\u002fup8dLdP6wcWmQ7398\u002f9ihcj8L14D+WQ4ts5\u002fvhPzVeukkMAuM\u002fqvHSTWIQ5D9KDAIrhxblP+kmMQisHOY\u002fiUFg5dAi5z8pXI\u002fC9SjoP8l2vp8aL+k\u002faJHtfD816j8IrBxaZDvrP30\u002fNV66Sew\u002fHVpkO99P7T+8dJMYBFbuP1yPwvUoXO8\u002f\u002ftR46SYx8D9OYhBYObTwP57vp8ZLN\u002fE\u002f7nw\u002fNV668T+oxks3iUHyP\u002fhT46WbxPI\u002fSOF6FK5H8z+YbhKDwMrzP+f7qfHSTfQ\u002fN4lBYOXQ9D+HFtnO91P1P9ejcD0K1\u002fU\u002fke18PzVe9j\u002fhehSuR+H2PzEIrBxaZPc\u002fgZVDi2zn9z\u002fRItv5fmr4PyGwcmiR7fg\u002fcT0K16Nw+T\u002fByqFFtvP5P3sUrkfhevo\u002fy6FFtvP9+j8bL90kBoH7P2q8dJMYBPw\u002fukkMAiuH\u002fD8K16NwPQr9P1pkO99Pjf0\u002fFK5H4XoU\u002fj9kO99PjZf+P7TIdr6fGv8\u002fBFYOLbKd\u002fz+q8dJNYhAAQFK4HoXrUQBA+n5qvHSTAECiRbbz\u002fdQAQH9qvHSTGAFAJzEIrBxaAUDP91PjpZsBQHe+nxov3QFAH4XrUbgeAkDHSzeJQWACQG8Sg8DKoQJAF9nO91PjAkD0\u002fdR46SYDQJzEILByaANARIts5\u002fupA0DsUbgehesDQJMYBFYOLQRAO99PjZduBEDjpZvEILAEQIts5\u002fup8QRAaJHtfD81BUAQWDm0yHYFQLgehetRuAVAYOXQItv5BUAIrBxaZDsGQLByaJHtfAZAWDm0yHa+BkA1XrpJDAIHQN0kBoGVQwdAhetRuB6FB0Atsp3vp8YHQNV46SYxCAhAfT81XrpJCEAlBoGVQ4sIQM3MzMzMzAhAqvHSTWIQCUBSuB6F61EJQPp+arx0kwlAokW28\u002f3UCUBKDAIrhxYKQPLSTWIQWApAmpmZmZmZCkBCYOXQItsKQB+F61G4HgtAx0s3iUFgC0BvEoPAyqELQBfZzvdT4wtAvp8aL90kDEBmZmZmZmYMQA4tsp3vpwxAtvP91HjpDECTGARWDi0NQDvfT42Xbg1A46WbxCCwDUCLbOf7qfENQDMzMzMzM ...
# Saved /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/santos_izmir2014_coding_exercises/plots/1st_excited_state_entropy_at_l_6_with_j2_0.html
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="4f7bc6a9-b89b-40ae-99a8-ada445bbb4a6" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4f7bc6a9-b89b-40ae-99a8-ada445bbb4a6")) {                    Plotly.newPlot(                        "4f7bc6a9-b89b-40ae-99a8-ada445bbb4a6",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMBYObTIdr4PwLByaJHtfA\u002fACKwcWmQ7D8ArhxbZzvcOwIPAyqFFtg7A2\u002fl+arx0DsAzMzMzMzMOwIts5\u002fup8Q3A46WbxCCwDcA730+Nl24NwJMYBFYOLQ3AtvP91HjpDMAOLbKd76cMwGZmZmZmZgzAvp8aL90kDMAX2c73U+MLwG8Sg8DKoQvAx0s3iUFgC8AfhetRuB4LwEJg5dAi2wrAmpmZmZmZCsDy0k1iEFgKwEoMAiuHFgrAokW28\\u002fupA8CcxCCwcmgDwPT91HjpJgPAF9nO91PjAsBvEoPAyqECwMdLN4lBYALAH4XrUbgeAsB3vp8aL90BwM\u002f3U+OlmwHAJzEIrBxaAcB\u002farx0kxgBwKJFtvP91ADA+n5qvHSTAMBSuB6F61EAwKrx0k1iEADABFYOLbKd\u002f7+0yHa+nxr\u002fv2Q730+Nl\u002f6\u002fFK5H4XoU\u002fr9aZDvfT439vwrXo3A9Cv2\u002fukkMAiuH\u002fL9qvHSTGAT8vxsv3SQGgfu\u002fy6FFtvP9+r97FK5H4Xr6v8HKoUW28\u002fm\u002fcT0K16Nw+b8hsHJoke34v9Ei2\u002fl+avi\u002fgZVDi2zn978xCKwcWmT3v+F6FK5H4fa\u002fke18PzVe9r\u002fXo3A9Ctf1v4cW2c73U\u002fW\u002fN4lBYOXQ9L\u002fn+6nx0k30v5huEoPAyvO\u002fSOF6FK5H87\u002f4U+Olm8Tyv6jGSzeJQfK\u002f7nw\u002fNV668b+e76fGSzfxv05iEFg5tPC\u002f\u002ftR46SYx8L9cj8L1KFzvv7x0kxgEVu6\u002fHVpkO99P7b99PzVeuknsvwisHFpkO+u\u002faJHtfD816r\u002fJdr6fGi\u002fpvylcj8L1KOi\u002fiUFg5dAi57\u002fpJjEIrBzmv0oMAiuHFuW\u002fqvHSTWIQ5L81XrpJDALjv5ZDi2zn++G\u002f9ihcj8L14L+sHFpkO9\u002ffv23n+6nx0t2\u002fLbKd76fG27\u002fufD81XrrZvwRWDi2ynde\u002fxSCwcmiR1b+F61G4HoXTv0a28\u002f3UeNG\u002fDAIrhxbZzr+Nl24Sg8DKvw4tsp3vp8a\u002fj8L1KFyPwr956SYxCKy8v3sUrkfherS\u002f+n5qvHSTqL\u002f8qfHSTWKQv\u002fyp8dJNYpA\u002f+n5qvHSTqD97FK5H4Xq0P3npJjEIrLw\u002fj8L1KFyPwj8OLbKd76fGP42XbhKDwMo\u002fDAIrhxbZzj9GtvP91HjRP4XrUbgehdM\u002fxSCwcmiR1T8EVg4tsp3XP+58PzVeutk\u002fLbKd76fG2z9t5\u002fup8dLdP6wcWmQ7398\u002f9ihcj8L14D+WQ4ts5\u002fvhPzVeukkMAuM\u002fqvHSTWIQ5D9KDAIrhxblP+kmMQisHOY\u002fiUFg5dAi5z8pXI\u002fC9SjoP8l2vp8aL+k\u002faJHtfD816j8IrBxaZDvrP30\u002fNV66Sew\u002fHVpkO99P7T+8dJMYBFbuP1yPwvUoXO8\u002f\u002ftR46SYx8D9OYhBYObTwP57vp8ZLN\u002fE\u002f7nw\u002fNV668T+oxks3iUHyP\u002fhT46WbxPI\u002fSOF6FK5H8z+YbhKDwMrzP+f7qfHSTfQ\u002fN4lBYOXQ9D+HFtnO91P1P9ejcD0K1\u002fU\u002fke18PzVe9j\u002fhehSuR+H2PzEIrBxaZPc\u002fgZVDi2zn9z\u002fRItv5fmr4PyGwcmiR7fg\u002fcT0K16Nw+T\u002fByqFFtvP5P3sUrkfhevo\u002fy6FFtvP9+j8bL90kBoH7P2q8dJMYBPw\u002fukkMAiuH\u002fD8K16NwPQr9P1pkO99Pjf0\u002fFK5H4XoU\u002fj9kO99PjZf+P7TIdr6fGv8\u002fBFYOLbKd\u002fz+q8dJNYhAAQFK4HoXrUQBA+n5qvHSTAECiRbbz\u002fdQAQH9qvHSTGAFAJzEIrBxaAUDP91PjpZsBQHe+nxov3QFAH4XrUbgeAkDHSzeJQWACQG8Sg8DKoQJAF9nO91PjAkD0\u002fdR46SYDQJzEILByaANARIts5\u002fupA0DsUbgehesDQJMYBFYOLQRAO99PjZduBEDjpZvEILAEQIts5\u002fup8QRAaJHtfD81BUAQWDm0yHYFQLgehetRuAVAYOXQItv5BUAIrBxaZDsGQLByaJHtfAZAWDm0yHa+BkA1XrpJDAIHQN0kBoGVQwdAhetRuB6FB0Atsp3vp8YHQNV46SYxCAhAfT81XrpJCEAlBoGVQ4sIQM3MzMzMzAhAqvHSTWIQCUBSuB6F61EJQPp+arx0kwlAokW28\u002f3UCUBKDAIrhxYKQPLSTWIQWApAmpmZmZmZCkBCYOXQItsKQB+F61G4HgtAx0s3iUFgC0BvEoPAyqELQBfZzvdT4wtAvp8aL90kDEBmZmZmZmYMQA4tsp3vpwxAtvP91HjpDECTGARWDi0NQDvfT42Xbg1A46WbxCCwDUCLbOf7qfENQDMzMzMzM ...
# Saved /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/santos_izmir2014_coding_exercises/plots/2nd_excited_state_entropy_at_l_6_with_j2_0.html
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f562b518-2561-45ec-909e-b62b98dc99bd" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f562b518-2561-45ec-909e-b62b98dc99bd")) {                    Plotly.newPlot(                        "f562b518-2561-45ec-909e-b62b98dc99bd",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMBYObTIdr4PwLByaJHtfA\u002fACKwcWmQ7D8ArhxbZzvcOwIPAyqFFtg7A2\u002fl+arx0DsAzMzMzMzMOwIts5\u002fup8Q3A46WbxCCwDcA730+Nl24NwJMYBFYOLQ3AtvP91HjpDMAOLbKd76cMwGZmZmZmZgzAvp8aL90kDMAX2c73U+MLwG8Sg8DKoQvAx0s3iUFgC8AfhetRuB4LwEJg5dAi2wrAmpmZmZmZCsDy0k1iEFgKwEoMAiuHFgrAokW28\\u002fupA8CcxCCwcmgDwPT91HjpJgPAF9nO91PjAsBvEoPAyqECwMdLN4lBYALAH4XrUbgeAsB3vp8aL90BwM\u002f3U+OlmwHAJzEIrBxaAcB\u002farx0kxgBwKJFtvP91ADA+n5qvHSTAMBSuB6F61EAwKrx0k1iEADABFYOLbKd\u002f7+0yHa+nxr\u002fv2Q730+Nl\u002f6\u002fFK5H4XoU\u002fr9aZDvfT439vwrXo3A9Cv2\u002fukkMAiuH\u002fL9qvHSTGAT8vxsv3SQGgfu\u002fy6FFtvP9+r97FK5H4Xr6v8HKoUW28\u002fm\u002fcT0K16Nw+b8hsHJoke34v9Ei2\u002fl+avi\u002fgZVDi2zn978xCKwcWmT3v+F6FK5H4fa\u002fke18PzVe9r\u002fXo3A9Ctf1v4cW2c73U\u002fW\u002fN4lBYOXQ9L\u002fn+6nx0k30v5huEoPAyvO\u002fSOF6FK5H87\u002f4U+Olm8Tyv6jGSzeJQfK\u002f7nw\u002fNV668b+e76fGSzfxv05iEFg5tPC\u002f\u002ftR46SYx8L9cj8L1KFzvv7x0kxgEVu6\u002fHVpkO99P7b99PzVeuknsvwisHFpkO+u\u002faJHtfD816r\u002fJdr6fGi\u002fpvylcj8L1KOi\u002fiUFg5dAi57\u002fpJjEIrBzmv0oMAiuHFuW\u002fqvHSTWIQ5L81XrpJDALjv5ZDi2zn++G\u002f9ihcj8L14L+sHFpkO9\u002ffv23n+6nx0t2\u002fLbKd76fG27\u002fufD81XrrZvwRWDi2ynde\u002fxSCwcmiR1b+F61G4HoXTv0a28\u002f3UeNG\u002fDAIrhxbZzr+Nl24Sg8DKvw4tsp3vp8a\u002fj8L1KFyPwr956SYxCKy8v3sUrkfherS\u002f+n5qvHSTqL\u002f8qfHSTWKQv\u002fyp8dJNYpA\u002f+n5qvHSTqD97FK5H4Xq0P3npJjEIrLw\u002fj8L1KFyPwj8OLbKd76fGP42XbhKDwMo\u002fDAIrhxbZzj9GtvP91HjRP4XrUbgehdM\u002fxSCwcmiR1T8EVg4tsp3XP+58PzVeutk\u002fLbKd76fG2z9t5\u002fup8dLdP6wcWmQ7398\u002f9ihcj8L14D+WQ4ts5\u002fvhPzVeukkMAuM\u002fqvHSTWIQ5D9KDAIrhxblP+kmMQisHOY\u002fiUFg5dAi5z8pXI\u002fC9SjoP8l2vp8aL+k\u002faJHtfD816j8IrBxaZDvrP30\u002fNV66Sew\u002fHVpkO99P7T+8dJMYBFbuP1yPwvUoXO8\u002f\u002ftR46SYx8D9OYhBYObTwP57vp8ZLN\u002fE\u002f7nw\u002fNV668T+oxks3iUHyP\u002fhT46WbxPI\u002fSOF6FK5H8z+YbhKDwMrzP+f7qfHSTfQ\u002fN4lBYOXQ9D+HFtnO91P1P9ejcD0K1\u002fU\u002fke18PzVe9j\u002fhehSuR+H2PzEIrBxaZPc\u002fgZVDi2zn9z\u002fRItv5fmr4PyGwcmiR7fg\u002fcT0K16Nw+T\u002fByqFFtvP5P3sUrkfhevo\u002fy6FFtvP9+j8bL90kBoH7P2q8dJMYBPw\u002fukkMAiuH\u002fD8K16NwPQr9P1pkO99Pjf0\u002fFK5H4XoU\u002fj9kO99PjZf+P7TIdr6fGv8\u002fBFYOLbKd\u002fz+q8dJNYhAAQFK4HoXrUQBA+n5qvHSTAECiRbbz\u002fdQAQH9qvHSTGAFAJzEIrBxaAUDP91PjpZsBQHe+nxov3QFAH4XrUbgeAkDHSzeJQWACQG8Sg8DKoQJAF9nO91PjAkD0\u002fdR46SYDQJzEILByaANARIts5\u002fupA0DsUbgehesDQJMYBFYOLQRAO99PjZduBEDjpZvEILAEQIts5\u002fup8QRAaJHtfD81BUAQWDm0yHYFQLgehetRuAVAYOXQItv5BUAIrBxaZDsGQLByaJHtfAZAWDm0yHa+BkA1XrpJDAIHQN0kBoGVQwdAhetRuB6FB0Atsp3vp8YHQNV46SYxCAhAfT81XrpJCEAlBoGVQ4sIQM3MzMzMzAhAqvHSTWIQCUBSuB6F61EJQPp+arx0kwlAokW28\u002f3UCUBKDAIrhxYKQPLSTWIQWApAmpmZmZmZCkBCYOXQItsKQB+F61G4HgtAx0s3iUFgC0BvEoPAyqELQBfZzvdT4wtAvp8aL90kDEBmZmZmZmYMQA4tsp3vpwxAtvP91HjpDECTGARWDi0NQDvfT42Xbg1A46WbxCCwDUCLbOf7qfENQDMzMzMzM ...
# Saved /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/santos_izmir2014_coding_exercises/plots/3rd_excited_state_entropy_at_l_6_with_j2_0.html
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="6418103a-f53d-40cd-a626-23cd3b85d14f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6418103a-f53d-40cd-a626-23cd3b85d14f")) {                    Plotly.newPlot(                        "6418103a-f53d-40cd-a626-23cd3b85d14f",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMBYObTIdr4PwLByaJHtfA\u002fACKwcWmQ7D8ArhxbZzvcOwIPAyqFFtg7A2\u002fl+arx0DsAzMzMzMzMOwIts5\u002fup8Q3A46WbxCCwDcA730+Nl24NwJMYBFYOLQ3AtvP91HjpDMAOLbKd76cMwGZmZmZmZgzAvp8aL90kDMAX2c73U+MLwG8Sg8DKoQvAx0s3iUFgC8AfhetRuB4LwEJg5dAi2wrAmpmZmZmZCsDy0k1iEFgKwEoMAiuHFgrAokW28\\u002fupA8CcxCCwcmgDwPT91HjpJgPAF9nO91PjAsBvEoPAyqECwMdLN4lBYALAH4XrUbgeAsB3vp8aL90BwM\u002f3U+OlmwHAJzEIrBxaAcB\u002farx0kxgBwKJFtvP91ADA+n5qvHSTAMBSuB6F61EAwKrx0k1iEADABFYOLbKd\u002f7+0yHa+nxr\u002fv2Q730+Nl\u002f6\u002fFK5H4XoU\u002fr9aZDvfT439vwrXo3A9Cv2\u002fukkMAiuH\u002fL9qvHSTGAT8vxsv3SQGgfu\u002fy6FFtvP9+r97FK5H4Xr6v8HKoUW28\u002fm\u002fcT0K16Nw+b8hsHJoke34v9Ei2\u002fl+avi\u002fgZVDi2zn978xCKwcWmT3v+F6FK5H4fa\u002fke18PzVe9r\u002fXo3A9Ctf1v4cW2c73U\u002fW\u002fN4lBYOXQ9L\u002fn+6nx0k30v5huEoPAyvO\u002fSOF6FK5H87\u002f4U+Olm8Tyv6jGSzeJQfK\u002f7nw\u002fNV668b+e76fGSzfxv05iEFg5tPC\u002f\u002ftR46SYx8L9cj8L1KFzvv7x0kxgEVu6\u002fHVpkO99P7b99PzVeuknsvwisHFpkO+u\u002faJHtfD816r\u002fJdr6fGi\u002fpvylcj8L1KOi\u002fiUFg5dAi57\u002fpJjEIrBzmv0oMAiuHFuW\u002fqvHSTWIQ5L81XrpJDALjv5ZDi2zn++G\u002f9ihcj8L14L+sHFpkO9\u002ffv23n+6nx0t2\u002fLbKd76fG27\u002fufD81XrrZvwRWDi2ynde\u002fxSCwcmiR1b+F61G4HoXTv0a28\u002f3UeNG\u002fDAIrhxbZzr+Nl24Sg8DKvw4tsp3vp8a\u002fj8L1KFyPwr956SYxCKy8v3sUrkfherS\u002f+n5qvHSTqL\u002f8qfHSTWKQv\u002fyp8dJNYpA\u002f+n5qvHSTqD97FK5H4Xq0P3npJjEIrLw\u002fj8L1KFyPwj8OLbKd76fGP42XbhKDwMo\u002fDAIrhxbZzj9GtvP91HjRP4XrUbgehdM\u002fxSCwcmiR1T8EVg4tsp3XP+58PzVeutk\u002fLbKd76fG2z9t5\u002fup8dLdP6wcWmQ7398\u002f9ihcj8L14D+WQ4ts5\u002fvhPzVeukkMAuM\u002fqvHSTWIQ5D9KDAIrhxblP+kmMQisHOY\u002fiUFg5dAi5z8pXI\u002fC9SjoP8l2vp8aL+k\u002faJHtfD816j8IrBxaZDvrP30\u002fNV66Sew\u002fHVpkO99P7T+8dJMYBFbuP1yPwvUoXO8\u002f\u002ftR46SYx8D9OYhBYObTwP57vp8ZLN\u002fE\u002f7nw\u002fNV668T+oxks3iUHyP\u002fhT46WbxPI\u002fSOF6FK5H8z+YbhKDwMrzP+f7qfHSTfQ\u002fN4lBYOXQ9D+HFtnO91P1P9ejcD0K1\u002fU\u002fke18PzVe9j\u002fhehSuR+H2PzEIrBxaZPc\u002fgZVDi2zn9z\u002fRItv5fmr4PyGwcmiR7fg\u002fcT0K16Nw+T\u002fByqFFtvP5P3sUrkfhevo\u002fy6FFtvP9+j8bL90kBoH7P2q8dJMYBPw\u002fukkMAiuH\u002fD8K16NwPQr9P1pkO99Pjf0\u002fFK5H4XoU\u002fj9kO99PjZf+P7TIdr6fGv8\u002fBFYOLbKd\u002fz+q8dJNYhAAQFK4HoXrUQBA+n5qvHSTAECiRbbz\u002fdQAQH9qvHSTGAFAJzEIrBxaAUDP91PjpZsBQHe+nxov3QFAH4XrUbgeAkDHSzeJQWACQG8Sg8DKoQJAF9nO91PjAkD0\u002fdR46SYDQJzEILByaANARIts5\u002fupA0DsUbgehesDQJMYBFYOLQRAO99PjZduBEDjpZvEILAEQIts5\u002fup8QRAaJHtfD81BUAQWDm0yHYFQLgehetRuAVAYOXQItv5BUAIrBxaZDsGQLByaJHtfAZAWDm0yHa+BkA1XrpJDAIHQN0kBoGVQwdAhetRuB6FB0Atsp3vp8YHQNV46SYxCAhAfT81XrpJCEAlBoGVQ4sIQM3MzMzMzAhAqvHSTWIQCUBSuB6F61EJQPp+arx0kwlAokW28\u002f3UCUBKDAIrhxYKQPLSTWIQWApAmpmZmZmZCkBCYOXQItsKQB+F61G4HgtAx0s3iUFgC0BvEoPAyqELQBfZzvdT4wtAvp8aL90kDEBmZmZmZmYMQA4tsp3vpwxAtvP91HjpDECTGARWDi0NQDvfT42Xbg1A46WbxCCwDUCLbOf7qfENQDMzMzMzM ...
# Saved /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/santos_izmir2014_coding_exercises/plots/4th_excited_state_entropy_at_l_6_with_j2_0.html
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c1399e6f-a81e-4495-a760-47cf7f4fd7f8" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c1399e6f-a81e-4495-a760-47cf7f4fd7f8")) {                    Plotly.newPlot(                        "c1399e6f-a81e-4495-a760-47cf7f4fd7f8",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMBYObTIdr4PwLByaJHtfA\u002fACKwcWmQ7D8ArhxbZzvcOwIPAyqFFtg7A2\u002fl+arx0DsAzMzMzMzMOwIts5\u002fup8Q3A46WbxCCwDcA730+Nl24NwJMYBFYOLQ3AtvP91HjpDMAOLbKd76cMwGZmZmZmZgzAvp8aL90kDMAX2c73U+MLwG8Sg8DKoQvAx0s3iUFgC8AfhetRuB4LwEJg5dAi2wrAmpmZmZmZCsDy0k1iEFgKwEoMAiuHFgrAokW28\\u002fupA8CcxCCwcmgDwPT91HjpJgPAF9nO91PjAsBvEoPAyqECwMdLN4lBYALAH4XrUbgeAsB3vp8aL90BwM\u002f3U+OlmwHAJzEIrBxaAcB\u002farx0kxgBwKJFtvP91ADA+n5qvHSTAMBSuB6F61EAwKrx0k1iEADABFYOLbKd\u002f7+0yHa+nxr\u002fv2Q730+Nl\u002f6\u002fFK5H4XoU\u002fr9aZDvfT439vwrXo3A9Cv2\u002fukkMAiuH\u002fL9qvHSTGAT8vxsv3SQGgfu\u002fy6FFtvP9+r97FK5H4Xr6v8HKoUW28\u002fm\u002fcT0K16Nw+b8hsHJoke34v9Ei2\u002fl+avi\u002fgZVDi2zn978xCKwcWmT3v+F6FK5H4fa\u002fke18PzVe9r\u002fXo3A9Ctf1v4cW2c73U\u002fW\u002fN4lBYOXQ9L\u002fn+6nx0k30v5huEoPAyvO\u002fSOF6FK5H87\u002f4U+Olm8Tyv6jGSzeJQfK\u002f7nw\u002fNV668b+e76fGSzfxv05iEFg5tPC\u002f\u002ftR46SYx8L9cj8L1KFzvv7x0kxgEVu6\u002fHVpkO99P7b99PzVeuknsvwisHFpkO+u\u002faJHtfD816r\u002fJdr6fGi\u002fpvylcj8L1KOi\u002fiUFg5dAi57\u002fpJjEIrBzmv0oMAiuHFuW\u002fqvHSTWIQ5L81XrpJDALjv5ZDi2zn++G\u002f9ihcj8L14L+sHFpkO9\u002ffv23n+6nx0t2\u002fLbKd76fG27\u002fufD81XrrZvwRWDi2ynde\u002fxSCwcmiR1b+F61G4HoXTv0a28\u002f3UeNG\u002fDAIrhxbZzr+Nl24Sg8DKvw4tsp3vp8a\u002fj8L1KFyPwr956SYxCKy8v3sUrkfherS\u002f+n5qvHSTqL\u002f8qfHSTWKQv\u002fyp8dJNYpA\u002f+n5qvHSTqD97FK5H4Xq0P3npJjEIrLw\u002fj8L1KFyPwj8OLbKd76fGP42XbhKDwMo\u002fDAIrhxbZzj9GtvP91HjRP4XrUbgehdM\u002fxSCwcmiR1T8EVg4tsp3XP+58PzVeutk\u002fLbKd76fG2z9t5\u002fup8dLdP6wcWmQ7398\u002f9ihcj8L14D+WQ4ts5\u002fvhPzVeukkMAuM\u002fqvHSTWIQ5D9KDAIrhxblP+kmMQisHOY\u002fiUFg5dAi5z8pXI\u002fC9SjoP8l2vp8aL+k\u002faJHtfD816j8IrBxaZDvrP30\u002fNV66Sew\u002fHVpkO99P7T+8dJMYBFbuP1yPwvUoXO8\u002f\u002ftR46SYx8D9OYhBYObTwP57vp8ZLN\u002fE\u002f7nw\u002fNV668T+oxks3iUHyP\u002fhT46WbxPI\u002fSOF6FK5H8z+YbhKDwMrzP+f7qfHSTfQ\u002fN4lBYOXQ9D+HFtnO91P1P9ejcD0K1\u002fU\u002fke18PzVe9j\u002fhehSuR+H2PzEIrBxaZPc\u002fgZVDi2zn9z\u002fRItv5fmr4PyGwcmiR7fg\u002fcT0K16Nw+T\u002fByqFFtvP5P3sUrkfhevo\u002fy6FFtvP9+j8bL90kBoH7P2q8dJMYBPw\u002fukkMAiuH\u002fD8K16NwPQr9P1pkO99Pjf0\u002fFK5H4XoU\u002fj9kO99PjZf+P7TIdr6fGv8\u002fBFYOLbKd\u002fz+q8dJNYhAAQFK4HoXrUQBA+n5qvHSTAECiRbbz\u002fdQAQH9qvHSTGAFAJzEIrBxaAUDP91PjpZsBQHe+nxov3QFAH4XrUbgeAkDHSzeJQWACQG8Sg8DKoQJAF9nO91PjAkD0\u002fdR46SYDQJzEILByaANARIts5\u002fupA0DsUbgehesDQJMYBFYOLQRAO99PjZduBEDjpZvEILAEQIts5\u002fup8QRAaJHtfD81BUAQWDm0yHYFQLgehetRuAVAYOXQItv5BUAIrBxaZDsGQLByaJHtfAZAWDm0yHa+BkA1XrpJDAIHQN0kBoGVQwdAhetRuB6FB0Atsp3vp8YHQNV46SYxCAhAfT81XrpJCEAlBoGVQ4sIQM3MzMzMzAhAqvHSTWIQCUBSuB6F61EJQPp+arx0kwlAokW28\u002f3UCUBKDAIrhxYKQPLSTWIQWApAmpmZmZmZCkBCYOXQItsKQB+F61G4HgtAx0s3iUFgC0BvEoPAyqELQBfZzvdT4wtAvp8aL90kDEBmZmZmZmYMQA4tsp3vpwxAtvP91HjpDECTGARWDi0NQDvfT42Xbg1A46WbxCCwDUCLbOf7qfENQDMzMzMzM ...
