# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb
from itertools import combinations
from scipy.sparse import coo_matrix
from scipy.sparse.linalg import eigsh
from scipy.linalg import svdvals

try:
    from numba import njit
except Exception:
    def njit(*args, **kwargs):
        if args and len(args) == 1 and callable(args[0]) and not kwargs:
            return args[0]

        def decorator(func):
            return func

        return decorator


@njit(cache=True)
def _build_cut_map_numba(states, L, ell):
    dim = states.shape[0]
    row_a = np.empty(dim, dtype=np.int32)
    row_b = np.empty(dim, dtype=np.int32)
    left_shift = L - ell
    left_mask = (np.uint64(1) << np.uint64(left_shift)) - np.uint64(1)
    right_mask = (np.uint64(1) << np.uint64(ell)) - np.uint64(1)

    for i in range(dim):
        state = states[i]
        row_a[i] = int((state >> np.uint64(left_shift)) & left_mask)
        row_b[i] = int(state & right_mask)

    return row_a, row_b


@njit(cache=True)
def _build_hamiltonian_triplets(states, index_map, L, pairs1, pairs2, J1xy, J1z, J2xy, J2z, kind_flag):
    dim = states.shape[0]
    n1 = pairs1.shape[0]
    n2 = pairs2.shape[0]
    if kind_flag == 0:
        max_nnz = dim + dim * n1
    else:
        max_nnz = dim + dim * (n1 + n2)

    rows = np.empty(max_nnz, dtype=np.int32)
    cols = np.empty(max_nnz, dtype=np.int32)
    vals = np.empty(max_nnz, dtype=np.float64)
    diag = np.zeros(dim, dtype=np.float64)
    one = np.uint64(1)
    cursor = 0

    for i in range(dim):
        state = states[i]

        for p in range(n1):
            a = pairs1[p, 0]
            b = pairs1[p, 1]
            pa = np.uint64(L - 1 - a)
            pb = np.uint64(L - 1 - b)
            bit_a = (state >> pa) & one
            bit_b = (state >> pb) & one
            if bit_a == bit_b:
                diag[i] += J1z / 4.0
            else:
                diag[i] -= J1z / 4.0
                if J1xy != 0.0:
                    flipped = state ^ ((one << pa) | (one << pb))
                    j = index_map[np.int64(flipped)]
                    rows[cursor] = i
                    cols[cursor] = j
                    vals[cursor] = J1xy / 2.0
                    cursor += 1

        if kind_flag == 1:
            for p in range(n2):
                a = pairs2[p, 0]
                b = pairs2[p, 1]
                pa = np.uint64(L - 1 - a)
                pb = np.uint64(L - 1 - b)
                bit_a = (state >> pa) & one
                bit_b = (state >> pb) & one
                if bit_a == bit_b:
                    diag[i] += J2z / 4.0
                else:
                    diag[i] -= J2z / 4.0
                    if J2xy != 0.0:
                        flipped = state ^ ((one << pa) | (one << pb))
                        j = index_map[np.int64(flipped)]
                        rows[cursor] = i
                        cols[cursor] = j
                        vals[cursor] = J2xy / 2.0
                        cursor += 1

    for i in range(dim):
        rows[cursor] = i
        cols[cursor] = i
        vals[cursor] = diag[i]
        cursor += 1

    return rows[:cursor], cols[:cursor], vals[:cursor]


class FastXXZChain:
    """Optimized fixed-Nup XXZ chain with cached basis, Hamiltonian, and entropy maps."""

    def __init__(self, L, Nup, periodic=True, J1xy=1.0, J1z=0.5, J2xy=0.0, J2z=0.0):
        self.L = int(L)
        self.Nup = int(Nup)
        self.periodic = bool(periodic)
        self.J1xy = float(J1xy)
        self.J1z = float(J1z)
        self.J2xy = float(J2xy)
        self.J2z = float(J2z)

        self.states = self._build_basis_states()
        self.index_map = self._build_index_map()
        self.pairs1 = np.asarray(self._pairs(1), dtype=np.int32)
        self.pairs2 = np.asarray(self._pairs(2), dtype=np.int32)
        self._entropy_cache = {}

    def _build_basis_states(self):
        states = []
        for positions in combinations(range(self.L), self.Nup):
            value = 0
            for site in positions:
                value |= 1 << (self.L - 1 - site)
            states.append(value)
        return np.asarray(states, dtype=np.uint64)

    def _build_index_map(self):
        size = 1 << self.L
        index_map = -np.ones(size, dtype=np.int32)
        for i, state in enumerate(self.states):
            index_map[int(state)] = i
        return index_map

    def _pairs(self, order):
        if order == 1:
            if self.periodic:
                return [(i, (i + 1) % self.L) for i in range(self.L)]
            return [(i, i + 1) for i in range(self.L - 1)]
        if order == 2:
            if self.periodic:
                return [(i, (i + 2) % self.L) for i in range(self.L)]
            return [(i, i + 2) for i in range(self.L - 2)]
        raise ValueError('order must be 1 or 2')

    def hilbert_dimension(self):
        return int(self.states.size)

    def build_hamiltonian(self, kind='nnn'):
        if kind not in {'nn', 'nnn'}:
            raise ValueError("kind must be 'nn' or 'nnn'.")

        kind_flag = 0 if kind == 'nn' else 1
        rows, cols, vals = _build_hamiltonian_triplets(
            self.states,
            self.index_map,
            self.L,
            self.pairs1,
            self.pairs2,
            self.J1xy,
            self.J1z,
            self.J2xy,
            self.J2z,
            kind_flag,
        )
        dim = self.hilbert_dimension()
        return coo_matrix((vals, (rows, cols)), shape=(dim, dim)).tocsr()

    def ground_state(self, kind='nnn'):
        H = self.build_hamiltonian(kind=kind)
        if H.shape[0] == 1:
            return float(H[0, 0]), np.array([1.0], dtype=float)
        eigvals, eigvecs = eigsh(H, k=1, which='SA', tol=1e-12, maxiter=100000)
        return float(eigvals[0]), eigvecs[:, 0]

    def _cut_map(self, ell):
        if ell in self._entropy_cache:
            return self._entropy_cache[ell]

        row_a, row_b = _build_cut_map_numba(self.states, self.L, ell)
        mapping = {
            'rowA': row_a,
            'rowB': row_b,
            'dimA': 1 << ell,
            'dimB': 1 << (self.L - ell),
        }
        self._entropy_cache[ell] = mapping
        return mapping

    def entropy_curve(self, kind='nnn', blocks=None):
        ground_energy, sector_state = self.ground_state(kind=kind)
        if blocks is None:
            blocks = range(1, self.L)
        block_list = sorted({int(block) for block in blocks if 0 < block < self.L})

        entropies = np.zeros(len(block_list), dtype=float)
        for i, ell in enumerate(block_list):
            data = self._cut_map(ell)
            psi_matrix = np.zeros((data['dimA'], data['dimB']), dtype=complex)
            psi_matrix[data['rowA'], data['rowB']] = sector_state
            svals = svdvals(psi_matrix)
            probs = svals**2
            probs = probs[probs > 1e-14]
            entropies[i] = float(-np.sum(probs * np.log(probs)))

        block_sizes = np.asarray(block_list, dtype=int)
        upper_bound = np.log(2.0) * np.minimum(block_sizes, self.L - block_sizes)
        return block_sizes, entropies, upper_bound, ground_energy

    def plot_entropy(self, kind='nnn', blocks=None, title=None):
        block_sizes, entropies, upper_bound, ground_energy = self.entropy_curve(kind=kind, blocks=blocks)
        fig, ax = plt.subplots(figsize=(8, 5))
        ax.plot(block_sizes, entropies, marker='o', linewidth=2, label='Entropy')
        ax.plot(block_sizes, upper_bound, '--', linewidth=2, label='Upper Bound')
        ax.set_xlabel('Block size l')
        ax.set_ylabel('S(l)')
        ax.set_title(title or f'Entanglement Entropy (E0 = {ground_energy:.6f})')
        ax.grid(True, alpha=0.3)
        ax.legend()
        plt.tight_layout()
        plt.show()


def half_filling_dimension(L):
    return comb(L, L // 2)


def recommended_max_L(limit_dim=200000):
    best = 0
    for L in range(2, 40, 2):
        if half_filling_dimension(L) <= limit_dim:
            best = L
    return best

# %%
# Interactive 3D surface for rotating the entropy landscape with J1xy fixed at 1 and J2xy fixed to zero.
from IPython.display import HTML, display
import plotly.graph_objects as go

L = 10
chain = FastXXZChain(
    L=L,
    Nup=L // 2,
    periodic=True,
    J1xy=1.0,
    J1z=0.0,
    J2xy=0.0,
    J2z=0.0,
)

J1z_values = np.round(np.linspace(-10.0, 10.0, 200), 3)
J2z_values = np.round(np.linspace(-10.0, 10.0, 200), 3)
S_grid = np.zeros((len(J2z_values), len(J1z_values)), dtype=float)
block = L // 2

for i, J2z in enumerate(J2z_values):
    for j, J1z in enumerate(J1z_values):
        chain.J1xy = 1.0
        chain.J1z = float(J1z)
        chain.J2xy = 0.0
        chain.J2z = float(J2z)
        _, entropies, _, _ = chain.entropy_curve(kind="nnn", blocks=[block])
        S_grid[i, j] = entropies[0]

z_min = float(np.nanmin(S_grid))
z_max = float(np.nanmax(S_grid))
plane_z = np.array([[z_min, z_max], [z_min, z_max]], dtype=float)
plane_y = np.array([[J2z_values[0], J2z_values[0]], [J2z_values[-1], J2z_values[-1]]], dtype=float)
plane_x_minus = np.full_like(plane_z, -1.0)
plane_x_plus = np.full_like(plane_z, 1.0)

fig = go.Figure()
fig.add_trace(
    go.Surface(
        x=J1z_values,
        y=J2z_values,
        z=S_grid,
        colorscale='Viridis',
        colorbar=dict(title='Entropy'),
        name='Entropy surface',
        showscale=True,
    )
)
fig.add_trace(
    go.Surface(
        x=plane_x_minus,
        y=plane_y,
        z=plane_z,
        surfacecolor=np.zeros_like(plane_z),
        colorscale=[[0, 'rgba(255, 255, 255, 0.15)'], [1, 'rgba(255, 255, 255, 0.15)']],
        showscale=False,
        opacity=0.25,
        name='J1z = -1',
        hoverinfo='skip',
    )
)
fig.add_trace(
    go.Surface(
        x=plane_x_plus,
        y=plane_y,
        z=plane_z,
        surfacecolor=np.zeros_like(plane_z),
        colorscale=[[0, 'rgba(255, 255, 255, 0.15)'], [1, 'rgba(255, 255, 255, 0.15)']],
        showscale=False,
        opacity=0.25,
        name='J1z = 1',
        hoverinfo='skip',
    )
)
fig.update_layout(
    title=f'Interactive half-chain entropy surface at L={L} with J1xy = 1 and J2xy = 0',
    scene=dict(
        xaxis_title='J1z',
        yaxis_title='J2z',
        zaxis_title='Half-chain entropy',
        camera=dict(eye=dict(x=1.6, y=1.6, z=1.0)),
    ),
    margin=dict(l=0, r=0, b=0, t=40),
)

display(HTML(fig.to_html(include_plotlyjs='cdn', full_html=False)))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="4516469f-d23b-452d-b223-4c9885282fe7" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4516469f-d23b-452d-b223-4c9885282fe7")) {                    Plotly.newPlot(                        "4516469f-d23b-452d-b223-4c9885282fe7",                        [{"colorbar":{"title":{"text":"Entropy"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"name":"Entropy surface","showscale":true,"x":{"dtype":"f8","bdata":"AAAAAAAAJMA\u002fNV66ScwjwAwCK4cWmSPATDeJQWBlI8AZBFYOLTIjwFg5tMh2\u002fiLAJQaBlUPLIsBkO99PjZciwDEIrBxaZCLAcT0K16MwIsA9CtejcP0hwH0\u002fNV66ySHASgwCK4eWIcCJQWDl0GIhwFYOLbKdLyHAlkOLbOf7IMBiEFg5tMggwKJFtvP9lCDAbxKDwMphIMCuR+F6FC4gwPYoXI\u002fC9R\u002fAdZMYBFaOH8AOLbKd7ycfwI2XbhKDwB7AJzEIrBxaHsCmm8QgsPIdwD81XrpJjB3Avp8aL90kHcBYObTIdr4cwNejcD0KVxzAcT0K16PwG8Dwp8ZLN4kbwIlBYOXQIhvACKwcWmS7GsCiRbbz\u002fVQawCGwcmiR7RnAukkMAiuHGcA5tMh2vh8ZwNNNYhBYuRjAUrgehetRGMDsUbgehesXwGq8dJMYhBfABFYOLbIdF8CDwMqhRbYWwB1aZDvfTxbAnMQgsHLoFcA1XrpJDIIVwLTIdr6fGhXATmIQWDm0FMDNzMzMzEwUwGZmZmZm5hPA5dAi2\u002fl+E8B\u002farx0kxgTwP7UeOkmsRLAmG4Sg8BKEsAX2c73U+MRwLByaJHtfBHAL90kBoEVEcDJdr6fGq8QwEjhehSuRxDAw\u002fUoXI\u002fCD8DByqFFtvMOwPT91HjpJg7A8tJNYhBYDcAlBoGVQ4sMwCPb+X5qvAvAVg4tsp3vCsBU46WbxCAKwIcW2c73UwnAhetRuB6FCMC4HoXrUbgHwLbz\u002fdR46QbA6SYxCKwcBsDn+6nx0k0FwBsv3SQGgQTAGQRWDi2yA8BMN4lBYOUCwEoMAiuHFgLAfT81XrpJAcB7FK5H4XoAwFyPwvUoXP+\u002fWDm0yHa+\u002fb++nxov3ST8v7pJDAIrh\u002fq\u002fIbByaJHt+L8dWmQ730\u002f3v4PAyqFFtvW\u002ff2q8dJMY9L\u002fl0CLb+X7yv+F6FK5H4fC\u002fj8L1KFyP7r+HFtnO91Prv1TjpZvEIOi\u002fTDeJQWDl5L8ZBFYOLbLhvyGwcmiR7dy\u002fukkMAiuH1r+q8dJNYhDQv4cW2c73U8O\u002fmpmZmZmZqb+amZmZmZmpP4cW2c73U8M\u002fqvHSTWIQ0D+6SQwCK4fWPyGwcmiR7dw\u002fGQRWDi2y4T9MN4lBYOXkP1TjpZvEIOg\u002fhxbZzvdT6z+PwvUoXI\u002fuP+F6FK5H4fA\u002f5dAi2\u002fl+8j9\u002farx0kxj0P4PAyqFFtvU\u002fHVpkO99P9z8hsHJoke34P7pJDAIrh\u002fo\u002fvp8aL90k\u002fD9YObTIdr79P1yPwvUoXP8\u002fexSuR+F6AEB9PzVeukkBQEoMAiuHFgJATDeJQWDlAkAZBFYOLbIDQBsv3SQGgQRA5\u002fup8dJNBUDpJjEIrBwGQLbz\...\u002f1UGkAIrBxaZLsaQIlBYOXQIhtA8KfGSzeJG0BxPQrXo\u002fAbQNejcD0KVxxAWDm0yHa+HEC+nxov3SQdQD81XrpJjB1AppvEILDyHUAnMQisHFoeQI2XbhKDwB5ADi2yne8nH0B1kxgEVo4fQPYoXI\u002fC9R9ArkfhehQuIEBvEoPAymEgQKJFtvP9lCBAYhBYObTIIECWQ4ts5\u002fsgQFYOLbKdLyFAiUFg5dBiIUBKDAIrh5YhQH0\u002fNV66ySFAPQrXo3D9IUBxPQrXozAiQDEIrBxaZCJAZDvfT42XIkAlBoGVQ8siQFg5tMh2\u002fiJAGQRWDi0yI0BMN4lBYGUjQAwCK4cWmSNAPzVeuknMI0AAAAAAAAAkQA=="},"y":{"dtype":"f8","bdata":"AAAAAAAAJMA\u002fNV66ScwjwAwCK4cWmSPATDeJQWBlI8AZBFYOLTIjwFg5tMh2\u002fiLAJQaBlUPLIsBkO99PjZciwDEIrBxaZCLAcT0K16MwIsA9CtejcP0hwH0\u002fNV66ySHASgwCK4eWIcCJQWDl0GIhwFYOLbKdLyHAlkOLbOf7IMBiEFg5tMggwKJFtvP9lCDAbxKDwMphIMCuR+F6FC4gwPYoXI\u002fC9R\u002fAdZMYBFaOH8AOLbKd7ycfwI2XbhKDwB7AJzEIrBxaHsCmm8QgsPIdwD81XrpJjB3Avp8aL90kHcBYObTIdr4cwNejcD0KVxzAcT0K16PwG8Dwp8ZLN4kbwIlBYOXQIhvACKwcWmS7GsCiRbbz\u002fVQawCGwcmiR7RnAukkMAiuHGcA5tMh2vh8ZwNNNYhBYuRjAUrgehetRGMDsUbgehesXwGq8dJMYhBfABFYOLbIdF8CDwMqhRbYWwB1aZDvfTxbAnMQgsHLoFcA1XrpJDIIVwLTIdr6fGhXATmIQWDm0FMDNzMzMzEwUwGZmZmZm5hPA5dAi2\u002fl+E8B\u002farx0kxgTwP7UeOkmsRLAmG4Sg8BKEsAX2c73U+MRwLByaJHtfBHAL90kBoEVEcDJdr6fGq8QwEjhehSuRxDAw\u002fUoXI\u002fCD8DByqFFtvMOwPT91HjpJg7A8tJNYhBYDcAlBoGVQ4sMwCPb+X5qvAvAVg4tsp3vCsBU46WbxCAKwIcW2c73UwnAhetRuB6FCMC4HoXrUbgHwLbz\u002fdR46QbA6SYxCKwcBsDn+6nx0k0FwBsv3SQGgQTAGQRWDi2yA8BMN4lBYOUCwEoMAiuHFgLAfT81XrpJAcB7FK5H4XoAwFyPwvUoXP+\u002fWDm0yHa+\u002fb++nxov3ST8v7pJDAIrh\u002fq\u002fIbByaJHt+L8dWmQ730\u002f3v4PAyqFFtvW\u002ff ...
