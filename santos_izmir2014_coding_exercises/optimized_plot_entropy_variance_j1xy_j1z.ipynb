# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb
from itertools import combinations
from scipy.sparse import coo_matrix
from scipy.sparse.linalg import eigsh
from scipy.linalg import svdvals

try:
    from numba import njit
except Exception:
    def njit(*args, **kwargs):
        if args and len(args) == 1 and callable(args[0]) and not kwargs:
            return args[0]

        def decorator(func):
            return func

        return decorator


@njit(cache=True)
def _build_cut_map_numba(states, L, ell):
    dim = states.shape[0]
    row_a = np.empty(dim, dtype=np.int32)
    row_b = np.empty(dim, dtype=np.int32)
    left_shift = L - ell
    left_mask = (np.uint64(1) << np.uint64(left_shift)) - np.uint64(1)
    right_mask = (np.uint64(1) << np.uint64(ell)) - np.uint64(1)

    for i in range(dim):
        state = states[i]
        row_a[i] = int((state >> np.uint64(left_shift)) & left_mask)
        row_b[i] = int(state & right_mask)

    return row_a, row_b


@njit(cache=True)
def _build_hamiltonian_triplets(states, index_map, L, pairs1, pairs2, J1xy, J1z, J2xy, J2z, kind_flag):
    dim = states.shape[0]
    n1 = pairs1.shape[0]
    n2 = pairs2.shape[0]
    if kind_flag == 0:
        max_nnz = dim + dim * n1
    else:
        max_nnz = dim + dim * (n1 + n2)

    rows = np.empty(max_nnz, dtype=np.int32)
    cols = np.empty(max_nnz, dtype=np.int32)
    vals = np.empty(max_nnz, dtype=np.float64)
    diag = np.zeros(dim, dtype=np.float64)
    one = np.uint64(1)
    cursor = 0

    for i in range(dim):
        state = states[i]

        for p in range(n1):
            a = pairs1[p, 0]
            b = pairs1[p, 1]
            pa = np.uint64(L - 1 - a)
            pb = np.uint64(L - 1 - b)
            bit_a = (state >> pa) & one
            bit_b = (state >> pb) & one
            if bit_a == bit_b:
                diag[i] += J1z / 4.0
            else:
                diag[i] -= J1z / 4.0
                if J1xy != 0.0:
                    flipped = state ^ ((one << pa) | (one << pb))
                    j = index_map[np.int64(flipped)]
                    rows[cursor] = i
                    cols[cursor] = j
                    vals[cursor] = J1xy / 2.0
                    cursor += 1

        if kind_flag == 1:
            for p in range(n2):
                a = pairs2[p, 0]
                b = pairs2[p, 1]
                pa = np.uint64(L - 1 - a)
                pb = np.uint64(L - 1 - b)
                bit_a = (state >> pa) & one
                bit_b = (state >> pb) & one
                if bit_a == bit_b:
                    diag[i] += J2z / 4.0
                else:
                    diag[i] -= J2z / 4.0
                    if J2xy != 0.0:
                        flipped = state ^ ((one << pa) | (one << pb))
                        j = index_map[np.int64(flipped)]
                        rows[cursor] = i
                        cols[cursor] = j
                        vals[cursor] = J2xy / 2.0
                        cursor += 1

    for i in range(dim):
        rows[cursor] = i
        cols[cursor] = i
        vals[cursor] = diag[i]
        cursor += 1

    return rows[:cursor], cols[:cursor], vals[:cursor]


class FastXXZChain:
    """Optimized fixed-Nup XXZ chain with cached basis, Hamiltonian, and entropy maps."""

    def __init__(self, L, Nup, periodic=True, J1xy=1.0, J1z=0.5, J2xy=0.0, J2z=0.0):
        self.L = int(L)
        self.Nup = int(Nup)
        self.periodic = bool(periodic)
        self.J1xy = float(J1xy)
        self.J1z = float(J1z)
        self.J2xy = float(J2xy)
        self.J2z = float(J2z)

        self.states = self._build_basis_states()
        self.index_map = self._build_index_map()
        self.pairs1 = np.asarray(self._pairs(1), dtype=np.int32)
        self.pairs2 = np.asarray(self._pairs(2), dtype=np.int32)
        self._entropy_cache = {}

    def _build_basis_states(self):
        states = []
        for positions in combinations(range(self.L), self.Nup):
            value = 0
            for site in positions:
                value |= 1 << (self.L - 1 - site)
            states.append(value)
        return np.asarray(states, dtype=np.uint64)

    def _build_index_map(self):
        size = 1 << self.L
        index_map = -np.ones(size, dtype=np.int32)
        for i, state in enumerate(self.states):
            index_map[int(state)] = i
        return index_map

    def _pairs(self, order):
        if order == 1:
            if self.periodic:
                return [(i, (i + 1) % self.L) for i in range(self.L)]
            return [(i, i + 1) for i in range(self.L - 1)]
        if order == 2:
            if self.periodic:
                return [(i, (i + 2) % self.L) for i in range(self.L)]
            return [(i, i + 2) for i in range(self.L - 2)]
        raise ValueError('order must be 1 or 2')

    def hilbert_dimension(self):
        return int(self.states.size)

    def build_hamiltonian(self, kind='nnn'):
        if kind not in {'nn', 'nnn'}:
            raise ValueError("kind must be 'nn' or 'nnn'.")

        kind_flag = 0 if kind == 'nn' else 1
        rows, cols, vals = _build_hamiltonian_triplets(
            self.states,
            self.index_map,
            self.L,
            self.pairs1,
            self.pairs2,
            self.J1xy,
            self.J1z,
            self.J2xy,
            self.J2z,
            kind_flag,
        )
        dim = self.hilbert_dimension()
        return coo_matrix((vals, (rows, cols)), shape=(dim, dim)).tocsr()

    def ground_state(self, kind='nnn'):
        H = self.build_hamiltonian(kind=kind)
        if H.shape[0] == 1:
            return float(H[0, 0]), np.array([1.0], dtype=float)
        eigvals, eigvecs = eigsh(H, k=1, which='SA', tol=1e-12, maxiter=100000)
        return float(eigvals[0]), eigvecs[:, 0]

    def _cut_map(self, ell):
        if ell in self._entropy_cache:
            return self._entropy_cache[ell]

        row_a, row_b = _build_cut_map_numba(self.states, self.L, ell)
        mapping = {
            'rowA': row_a,
            'rowB': row_b,
            'dimA': 1 << ell,
            'dimB': 1 << (self.L - ell),
        }
        self._entropy_cache[ell] = mapping
        return mapping

    def entropy_curve(self, kind='nnn', blocks=None):
        ground_energy, sector_state = self.ground_state(kind=kind)
        if blocks is None:
            blocks = range(1, self.L)
        block_list = sorted({int(block) for block in blocks if 0 < block < self.L})

        entropies = np.zeros(len(block_list), dtype=float)
        for i, ell in enumerate(block_list):
            data = self._cut_map(ell)
            psi_matrix = np.zeros((data['dimA'], data['dimB']), dtype=complex)
            psi_matrix[data['rowA'], data['rowB']] = sector_state
            svals = svdvals(psi_matrix)
            probs = svals**2
            probs = probs[probs > 1e-14]
            entropies[i] = float(-np.sum(probs * np.log(probs)))

        block_sizes = np.asarray(block_list, dtype=int)
        upper_bound = np.log(2.0) * np.minimum(block_sizes, self.L - block_sizes)
        return block_sizes, entropies, upper_bound, ground_energy

    def plot_entropy(self, kind='nnn', blocks=None, title=None):
        block_sizes, entropies, upper_bound, ground_energy = self.entropy_curve(kind=kind, blocks=blocks)
        fig, ax = plt.subplots(figsize=(8, 5))
        ax.plot(block_sizes, entropies, marker='o', linewidth=2, label='Entropy')
        ax.plot(block_sizes, upper_bound, '--', linewidth=2, label='Upper Bound')
        ax.set_xlabel('Block size l')
        ax.set_ylabel('S(l)')
        ax.set_title(title or f'Entanglement Entropy (E0 = {ground_energy:.6f})')
        ax.grid(True, alpha=0.3)
        ax.legend()
        plt.tight_layout()
        plt.show()


def half_filling_dimension(L):
    return comb(L, L // 2)


def recommended_max_L(limit_dim=200000):
    best = 0
    for L in range(2, 40, 2):
        if half_filling_dimension(L) <= limit_dim:
            best = L
    return best

# %%
# Interactive 3D surface of half-chain entropy variance over the first five energy levels on (J1xy, J1z) with J2 fixed to zero.
from IPython.display import HTML, display
import plotly.graph_objects as go
from scipy.sparse.linalg import eigsh

L = 6
chain = FastXXZChain(
    L=L,
    Nup=L // 2,
    periodic=True,
    J1xy=0.0,
    J1z=0.0,
    J2xy=0.0,
    J2z=0.0,
)

J1xy_values = np.round(np.linspace(-4.0, 4.0, 25), 3)
J1z_values = np.round(np.linspace(-4.0, 4.0, 25), 3)
block = L // 2
variance_grid = np.full((len(J1z_values), len(J1xy_values)), np.nan, dtype=float)

for i, J1z in enumerate(J1z_values):
    for j, J1xy in enumerate(J1xy_values):
        # Skip the trivial all-zero Hamiltonian point where ARPACK can fail.
        if abs(J1xy) < 1e-12 and abs(J1z) < 1e-12:
            continue

        chain.J1xy = float(J1xy)
        chain.J1z = float(J1z)
        chain.J2xy = 0.0
        chain.J2z = 0.0

        H = chain.build_hamiltonian(kind="nn")
        k = min(5, H.shape[0] - 1)
        if k < 2:
            continue

        evals, evecs = eigsh(H, k=k, which="SA", tol=1e-10, maxiter=50000)
        order = np.argsort(evals)
        evecs = evecs[:, order]

        cut_map = chain._cut_map(block)
        psi_shape = (cut_map["dimA"], cut_map["dimB"])
        level_entropies = []

        for level in range(min(5, evecs.shape[1])):
            psi_matrix = np.zeros(psi_shape, dtype=complex)
            psi_matrix[cut_map["rowA"], cut_map["rowB"]] = evecs[:, level]
            svals = np.linalg.svd(psi_matrix, compute_uv=False)
            probs = svals**2
            probs = probs[probs > 1e-14]
            level_entropies.append(float(-np.sum(probs * np.log(probs))))

        variance_grid[i, j] = float(np.var(level_entropies, ddof=0))

fig = go.Figure(
    data=[
        go.Surface(
            x=J1xy_values,
            y=J1z_values,
            z=variance_grid,
            colorscale="Viridis",
            colorbar=dict(title="Entropy variance"),
        )
    ]
)
fig.update_layout(
    title=f"Interactive half-chain entropy variance at L={L} over (J1xy, J1z) with J2 = 0",
    scene=dict(
        xaxis_title="J1xy",
        yaxis_title="J1z",
        zaxis_title="Variance of half-chain entropy",
        camera=dict(eye=dict(x=1.6, y=1.6, z=1.0)),
    ),
    margin=dict(l=0, r=0, b=0, t=40),
)

display(HTML(fig.to_html(include_plotlyjs="cdn", full_html=False)))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c15064d8-0ebe-47be-8b2c-5f4885df360c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c15064d8-0ebe-47be-8b2c-5f4885df360c")) {                    Plotly.newPlot(                        "c15064d8-0ebe-47be-8b2c-5f4885df360c",                        [{"colorbar":{"title":{"text":"Entropy variance"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAAEMC8dJMYBFYNwESLbOf7qQrAAAAAAAAACMC8dJMYBFYFwESLbOf7qQLAAAAAAAAAAMB56SYxCKz6v4cW2c73U\u002fW\u002fAAAAAAAA8L\u002fy0k1iEFjlvx1aZDvfT9W\u002fAAAAAAAAAAAdWmQ730\u002fVP\u002fLSTWIQWOU\u002fAAAAAAAA8D+HFtnO91P1P3npJjEIrPo\u002fAAAAAAAAAEBEi2zn+6kCQLx0kxgEVgVAAAAAAAAACEBEi2zn+6kKQLx0kxgEVg1AAAAAAAAAEEA="},"y":{"dtype":"f8","bdata":"AAAAAAAAEMC8dJMYBFYNwESLbOf7qQrAAAAAAAAACMC8dJMYBFYFwESLbOf7qQLAAAAAAAAAAMB56SYxCKz6v4cW2c73U\u002fW\u002fAAAAAAAA8L\u002fy0k1iEFjlvx1aZDvfT9W\u002fAAAAAAAAAAAdWmQ730\u002fVP\u002fLSTWIQWOU\u002fAAAAAAAA8D+HFtnO91P1P3npJjEIrPo\u002fAAAAAAAAAEBEi2zn+6kCQLx0kxgEVgVAAAAAAAAACEBEi2zn+6kKQLx0kxgEVg1AAAAAAAAAEEA="},"z":{"dtype":"f8","bdata":"zgE5aLYTrj8OIWPjge+qP902BWCH+6g\u002fUgdkkC3Qoz\u002ftGUR\u002fUuiEPzjpZtZ2x3Q\u002f7R2YmI7qTj92TexRueR5P0Or2bCZ8YU\u002fjlwCP0L4ij+V4R\u002f8aTmTPxtp22RKN5E\u002fMjS776QPrj+qWrpm+xqQP2v7M\u002fku9Y0\u002f2cu85GG\u002fhj83ZUPnuOuBP3UUyWHdWmo\u002fxFkbLP8qVj9veEBUFeNyP9p9ryT+fYs\u002fIvTHQO6WpD8KK+STJICpP1bq9GsGjK0\u002fVerh10Jerj\u002fgT08mmtWuP+Vo4H1xFa8\u002fWis+OMKirD\u002fYzUDEbTaoPzdE3v9XxaI\u002fWg0b7comhD+YiRy6ZEtYP41MelFXElo\u002f27LP5lFyfj8ArR3Z4fKJP2sq\u002fJYN+4k\u002fgq5RJIsxkj+B3MEmBs+0Py4pZW3WuZI\u002flW1v+2Riiz9NtGYK0fKOP0\u002fRHcIUDoA\u002fhcHYxKAeXz\u002fI9qIogfloPxrJCu4JU4M\u002fMaZAFxjloj+3uXqmsnmnPzXv7vFq9qo\u002fvaOO6d2grT8coC8UGhewP66jfTRlVLE\u002frvgLExgbsD91\u002fjju3YyvP1p0eWYYVKo\u002fqmOZ2PXcpj+z3zubyvuIP\u002fWo6NQBZnU\u002fkthbmnqOYD9yb\u002fB4y\u002f11P44rsOZ1DYo\u002fsXZfy2qokz\u002fivRNLW+WQP8O3EQakSLs\u002flm\u002fCa28Tkj\u002f4JCGXtXKPPynWIdr+VIQ\u002fwt3vH+SNdj97pDKVe8hvP9w9E6ylWnc\u002fddqHp0fJhz8SHkQNbSSnPwvu2K8Uwqw\u002fujewlTLXrT87ZbFv1L6wP1q53tzskbE\u002fGkBFlhjFsD\u002fz8ygkKaSwP3nPrKAkRLA\u002fypaSxxzNrz824+7+VPapPyEgP1iGsaU\u002f5tanIvVzij8lCwHxtaxlP+L5Fv8D5Wg\u002fyekNJ1jshD88Ndp\u002faQ+SP4NgaxksvJM\u002fg54er0E5mD8gH6REcueSP2XcVuON6I0\u002f2mZy94FPgz+iXkfLnPJHP2La+8za7Fs\u002flsU06kBRiD9uuGMJw4mmP5KaUhHuVqs\u002fzZd7DqDDrT8Dv7oxwqyvP8x4z7G0rrA\u002fwKNrdeB2sT8sTI5nKgOyP2GJZAwEB7E\u002fP+5BnuhPsj+zT2ZobwCxPz1MpltT+68\u002fcFVvIbatqj8XJX3PC1GkP6hrcXedZIE\u002fyyRcOcRoaD8qegyR0URzP4mWnaazW4g\u002fJmCknxqckz\u002fIbrOVxKeqP5hCg0nc7ZE\u002f6tQt+mngjT8wLfUTGoCCP\u002f4spKgQdmo\u002fzB1Y+91OgT+OjlQL3VKkP5DEhYNu+ak\u002fcLMj57BgrT9qEdkEt0ivP72BXguf6K8\u002f9pAK64TZsD+vWHpSwSqzP3yLMNcjsbA\u002fP7wIC9fjsD+NiKWD7eaxP64kyprMxLE\u002fcJJ\u002f26MXsD8+jMSqES2uP4nLe3jCLqk\u002fQvkEAreNkT91bWIuoFRxP\u002fDBUnR6SXg\u002fRSBMSaTjgj9qCLk34uyQP6oP9T0VlbE\u002fCXloNP\u002fHkD9lbxoa2viHP9ZoAjc17Wg\u002f4HmfrxcjYj8F3DznBhKSP6MVHRvub6o\u002f4E7EkOfVrz8mEmt510yxPzoyEKb6prE\u002fQs\u002fokpJ+sT\u002f1wfHKl3CyP3c85YaYlrE\u002fWq9qTpWerj86Oollw6axP8G7vwDud7E\u002fhyNs5KQstD\u002fd9WDieKewPyMyYguoI7E\u002fBXLuFrSLrz+0Q3AzjwSpPzI4a\u002f9zaII\u002fSRu1GOhmVj+L4X6xTOd8P2EIlTNwGpE\u002fYzsSwcEmfz+FuGvil\u002faQP2hUcUs1rIA\u002fGgL\u002fV3q8Zz+qmfEjE\u002faFP9LmxX+xz6c\u002fotz\u002fO05xrz+hvV+HAiGxP38g0+FAFLI\u002fxFjFwMi0sz+CZTYwuBywP+JNuyYobrA\u002fpb\u002f16FKcrj+7Vs8n1qyuP431u1b8664\u002fh ...
