# %% [markdown]
# # Unit Testing Notebook
#
# This notebook runs the unit test suite for the `EE_QuSpin_Method` package. Make sure to select your `.venv` kernel before running. Tests will be run with `pytest`.

# %%
import sys
import subprocess
print('python exe:', sys.executable)

# Run pytest for the package tests.
# The command prints live output into the notebook's stdout.
proc = subprocess.run([sys.executable, '-m', 'pytest', '-q', 'EE_QuSpin_Method/tests'], check=False)
print('pytest exit code:', proc.returncode)
# Out:
# python exe: /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/.venv/bin/python
# ..F.                                                                     [100%]
# =================================== FAILURES ===================================
# _____________________ test_entanglement_and_magnetisation ______________________
#
#     def test_entanglement_and_magnetisation():
#         cfg = ModelConfig(L=4)
#         b = build_basis(cfg)
#         # all-up product state corresponds to basis.states[0]
#         import numpy as np
#         vec = np.zeros(b.Ns, dtype=complex)
#         vec[0] = 1.0
#         # entanglement should be zero for product state
#         from EE_QuSpin_Method.quspin_chain.observables import entanglement_entropy, magnetisation
#         sent = entanglement_entropy(b, vec, sub_sys_A=list(range(cfg.L // 2)))
#         m = magnetisation(b, vec)
#         assert np.isclose(sent, 0.0)
# >       assert np.isclose(m, cfg.L)
# E       AssertionError: assert np.False_
# E        +  where np.False_ = <function isclose at 0x10205cc70>(2.0, 4)
# E        +    where <function isclose at 0x10205cc70> = <module 'numpy' from '/Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/.venv/lib/python3.12/site-packages/numpy/__init__.py'>.isclose
# E        +    and   4 = ModelConfig(L=4, Jxy=1.0, Jz=1.0, Jxy2=0.0, Jz2=0.0, pbc=True, basis_kwargs={}).L
#
# EE_QuSpin_Method/tests/test_basic.py:45: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# Hermiticity check passed!
# Symmetry checks passed!
# =============================== warnings summary ===============================
# EE_QuSpin_Method/tests/test_basic.py::test_entanglement_and_magnetisation
# EE_QuSpin_Method/tests/test_basic.py::test_run_small_sweep
#   /Users/matthewconway/Documents/GitHub/HamiltonTrust_2026_Spin_Chains/EE_QuSpin_Method/quspin_chain/observables.py:56: ComplexWarning: Casting complex values to real discards the imaginary part
#     return float(np.vdot(state, Sz.dot(state)))
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED EE_QuSpin_Method/tests/test_basic.py::test_entanglement_and_magnetisation - AssertionError: assert np.False_
# 1 failed, 3 passed, 2 warnings in 2.02s
# pytest exit code: 1

# %% [markdown]
# If tests were skipped due to missing `quspin`, install the package into the `.venv` and re-run this notebook.
